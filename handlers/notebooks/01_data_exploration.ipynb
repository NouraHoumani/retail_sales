# %%
import pandas as pd

# Replace with YOUR actual path
df = pd.read_csv(r'C:\Users\Me2\retail-sales-de\data\raw\online_retail.csv', encoding='ISO-8859-1')
print("Sample dates from CSV:")
print(df['InvoiceDate'].head(10))
print("\nDate format appears to be:")
print(df['InvoiceDate'].iloc[0])
# Out:
# Sample dates from CSV:
# 0    2010-12-01 08:26:00
# 1    2010-12-01 08:26:00
# 2    2010-12-01 08:26:00
# 3    2010-12-01 08:26:00
# 4    2010-12-01 08:26:00
# 5    2010-12-01 08:26:00
# 6    2010-12-01 08:26:00
# 7    2010-12-01 08:28:00
# 8    2010-12-01 08:28:00
# 9    2010-12-01 08:34:00
# Name: InvoiceDate, dtype: object
#
# Date format appears to be:
# 2010-12-01 08:26:00
